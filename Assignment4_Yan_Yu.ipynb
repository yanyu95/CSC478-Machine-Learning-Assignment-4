# %% [markdown]
# # 1
# # a

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
column_names = pd.read_csv('segmentation_names.txt', header=None)
column_names = np.array(column_names)
column_names = column_names.tolist()
column_names = sum(column_names, [])

seg = pd.read_csv('segmentation_data.txt', header=None)
seg.columns = column_names

classes = pd.read_csv('segmentation_classes.txt', delimiter="\t", header= None, index_col=0)

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
min_max_scaler.fit(seg)
seg_norm = min_max_scaler.fit_transform(seg)

# %% [markdown]
# # b

# %%
from sklearn.cluster import KMeans 
kmeans = KMeans(n_clusters=7, max_iter=500, verbose=1)

# %%
kmeans.fit(seg_norm)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 421.00279241
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 392.418231916
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 387.265002269
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 384.594740591
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 382.262053668
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 380.57209747
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 378.374108209
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 375.735497717
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 374.642484542
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 374.141115528
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 373.851154748
# start iteration
# ...

# %%
pd.DataFrame(kmeans.cluster_centers_, columns=[seg.columns])
# Out:
#    REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# 0             0.253603             0.459865                 0.0
# 1             0.302506             0.530862                 0.0
# 2             0.513994             0.808937                 0.0
# 3             0.535099             0.150167                 0.0
# 4             0.251678             0.392749                 0.0
# 5             0.748274             0.532041                 0.0
# 6             0.769063             0.425930                 0.0
#
#    SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# 0              0.026346              0.013746    0.037337  0.002370
# 1              0.052260              0.046610    0.100817  0.009420
# 2              0.077441              0.005051    0.054474  0.001407
# 3              0.027778              0.001667    0.030228  0.000543
# 4              0.075622              0.019403    0.077657  0.004149
# ...

# %%
pred = kmeans.predict(seg_norm)

# %%
from sklearn.metrics import completeness_score, homogeneity_score
classes = np.array(classes)
classes = classes.tolist()
classes = sum(classes, [])
print('Completeness is ', completeness_score(classes,pred))
print('Homogeneity is ', homogeneity_score(classes,pred))
# Out:
# Completeness is  0.611737468433
# Homogeneity is  0.610049991469

# %% [markdown]
# # c

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=7)
seg_trans = pca.fit(seg_norm).transform(seg_norm)

# %%
np.set_printoptions(precision=2,suppress=True)
print(seg_trans)
# Out:
# [[-0.69  0.53  0.25 ..., -0.08  0.05 -0.05]
#  [-0.67  0.51  0.34 ..., -0.04  0.06 -0.04]
#  [-0.71  0.77 -0.16 ..., -0.17  0.04 -0.06]
#  ...,
#  [-0.51 -0.13 -0.08 ..., -0.03 -0.03 -0.11]
#  [-0.48 -0.09 -0.16 ...,  0.   -0.   -0.09]
#  [-0.44 -0.11 -0.05 ...,  0.02 -0.21  0.15]]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [ 0.61  0.13  0.1   0.05  0.04  0.02  0.02]

# %% [markdown]
# # 7 components can explain 97% of the variance

# %% [markdown]
# # d

# %%
kmeans.fit(seg_trans)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 330.871763256
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 317.06388359
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 314.229915865
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 312.363978278
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 309.953897608
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 308.968962004
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 308.726643227
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 308.537049592
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 308.292625355
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 307.73176064
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 307.340511159
# start iteration
# ...

# %%
pred = kmeans.predict(seg_trans)

# %%
print('Completeness is ', completeness_score(classes,pred))
print('Homogeneity is ', homogeneity_score(classes,pred))
# Out:
# Completeness is  0.611298362648
# Homogeneity is  0.609645388271

# %% [markdown]
# # e
# # The completeness and homogeneity after implementing PCA are similar with  the two before implementing PCA. However the computation efficiency is improved with PCA.

# %% [markdown]
# # 2
# # a

# %%
def load_jokes(file):
    jokes = np.genfromtxt(file, delimiter=',', dtype=str)
    jokes = np.array(jokes[:,1])
    return jokes

# %%
jokes = load_jokes('jokes.csv')

# %%
jokes[0]
# Out:
# 'A man visits the doctor. The doctor says "I have bad news for you.You have cancer and Alzheimer\'s disease". The man replies "Well thank God I don\'t have cancer!"'

# %%
jester = np.genfromtxt('modified_jester_data.csv', delimiter=',')

# %%
jester
# Out:
# array([[  3.18,  19.79,   1.34, ...,   0.  ,   0.  ,   0.  ],
#        [ 15.08,  10.71,  17.36, ...,  11.34,   6.68,  12.07],
#        [  0.  ,   0.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        ...,
#        [ 16.58,  16.63,  15.85, ...,   0.  ,   0.  ,   0.  ],
#        [  3.67,   4.45,   3.67, ...,   3.77,   3.77,   3.28],
#        [  9.88,  11.73,   9.16, ...,   0.  ,   0.  ,   0.  ]])

# %% [markdown]
# # b

# %%
from numpy import *
from numpy import linalg as la

# %%
def ecludSim(inA,inB):
    return 1.0 / (1.0 + la.norm(inA - inB))

def pearsSim(inA,inB):
    if len(inA) < 3 : return 1.0
    return 0.5 + 0.5 * corrcoef(inA, inB, rowvar = 0)[0][1]

def cosSim(inA,inB):
    num = float(inA.T * inB)
    denom = la.norm(inA)*la.norm(inB)
    return 0.5 + 0.5 * (num / denom)

# %%
def standEst(dataMat, user, simMeas, item):
    n = shape(dataMat)[1]
    simTotal = 0.0; ratSimTotal = 0.0
    for j in range(n):
        userRating = dataMat[user,j]
        if userRating == 0: continue
        overLap = nonzero(logical_and(dataMat[:,item]>0, \
                                      dataMat[:,j]>0))[0]
        if len(overLap) == 0: similarity = 0
        else: similarity = simMeas(dataMat[overLap,item], \
                                   dataMat[overLap,j])
        #print 'the %d and %d similarity is: %f' % (item, j, similarity)
        simTotal += similarity
        ratSimTotal += similarity * userRating
    if simTotal == 0: return 0
    else: return ratSimTotal/simTotal

# %%
def svdEst(dataMat, user, simMeas, item):
    n = shape(dataMat)[1]
    simTotal = 0.0; ratSimTotal = 0.0
    data=mat(dataMat)
    U,Sigma,VT = la.svd(data)
    Sig4 = mat(eye(4)*Sigma[:4]) #arrange Sig4 into a diagonal matrix
    xformedItems = data.T * U[:,:4] * Sig4.I  #create transformed items
    for j in range(n):
        userRating = data[user,j]
        if userRating == 0 or j==item: continue
        similarity = simMeas(xformedItems[item,:].T,\
                             xformedItems[j,:].T)
        #print 'the %d and %d similarity is: %f' % (item, j, similarity)
        simTotal += similarity
        ratSimTotal += similarity * userRating
    if simTotal == 0: return 0
    else: return ratSimTotal/simTotal

# %%
def cross_validate_user(dataMat, user, test_ratio, estMethod=standEst, simMeas=pearsSim):
    number_of_items = np.shape(dataMat)[1]
    rated_items_by_user = np.array([i for i in range(number_of_items) if dataMat[user,i]>0])
    test_size = int(test_ratio * len(rated_items_by_user))
    test_indices = np.random.randint(0, len(rated_items_by_user), test_size)
    withheld_items = rated_items_by_user[test_indices]
    original_user_profile = np.copy(dataMat[user])
    dataMat[user, withheld_items] = 0 # So that the withheld test items is not used in the rating estimation below
    error_u = 0.0
    count_u = len(withheld_items)

    # Compute absolute error for user u over all test items
    for item in withheld_items:
        # Estimate rating on the withheld item
        estimatedScore = estMethod(dataMat, user, simMeas, item)
        error_u = error_u + abs(estimatedScore - original_user_profile[item])
    # Now restore ratings of the withheld items to the user profile
    for item in withheld_items:
        dataMat[user, item] = original_user_profile[item]

    # Return sum of absolute errors and the count of test cases for this user
    # Note that these will have to be accumulated for each user to compute MAE
    return error_u, count_u

# %%
def test(dataMat, test_ratio, estMethod, name):
    total_error = 0
    total_count = 0
    for u in range(jester.shape[0]):
        error , count = cross_validate_user(dataMat, u, test_ratio, estMethod, simMeas=pearsSim)
        total_error += abs(error)
        total_count += count
    MAE = total_error/total_count
    print('Mean Absoloute Error for ', name,' : ', MAE)

# %%
test(jester, 0.2, standEst, 'standard item-based')
# Out:
# Mean Absoloute Error for  standard item-based  :  3.68231981173

# %%
test(jester, 0.2, svdEst, 'svd item-based')
# Out:
# Mean Absoloute Error for  svd item-based  :  3.6350199905

# %% [markdown]
# # The MAE of standard item-based is slightly higher than the MAE of svd item-based.

# %% [markdown]
# #  c

# %%
jester
# Out:
# array([[  0.  ,   0.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        [ 15.08,   0.  ,  17.36, ...,   0.  ,   6.68,  12.07],
#        [  0.  ,   0.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        ...,
#        [ 16.58,  16.63,  15.85, ...,   0.  ,   0.  ,   0.  ],
#        [  3.67,   4.45,   3.67, ...,   3.77,   3.77,   3.28],
#        [  9.88,  11.73,   9.16, ...,   0.  ,   0.  ,   0.  ]])

# %%
jester.T
# Out:
# array([[  0.  ,  15.08,   0.  , ...,  16.58,   3.67,   9.88],
#        [  0.  ,   0.  ,   0.  , ...,  16.63,   4.45,  11.73],
#        [  0.  ,  17.36,   0.  , ...,  15.85,   3.67,   9.16],
#        ...,
#        [  0.  ,   0.  ,   0.  , ...,   0.  ,   3.77,   0.  ],
#        [  0.  ,   6.68,   0.  , ...,   0.  ,   3.77,   0.  ],
#        [  0.  ,  12.07,   0.  , ...,   0.  ,   3.28,   0.  ]])

# %%
def print_most_similar_jokes(dataMat, jokes, queryJoke, k, metric=pearsSim):
    simi = []
    for j in [ v for v in range(dataMat.shape[1]) if v != queryJoke ]:
        score = metric(dataMat.T[queryJoke], dataMat.T[j])
        simi.append(score)
    simi = np.array(simi)
    idx = np.argsort(-simi)
    
    print('Selected joke:', '\n')
    print(jokes[queryJoke], '\n')
    print('Top 5 Recommended jokes are :', '\n')
    
    for jk in idx[:5]:
        print(jokes[jk], '\n')

# %%
print_most_similar_jokes(jester, jokes, 3, 5,metric=pearsSim)
# Out:
# Selected joke:
#
# Q. What's the difference between a man and a toilet? A. A toilet doesn't follow you around after you use it.
#
# Top 5 Recommended jokes are :
#
# Q: What is the Australian word for a boomerang that won't   come back? A: A stick
#
# Q. Did you hear about the dyslexic devil worshipper? A. He sold his soul to Santa.
#
# Q. What's 200 feet long and has 4 teeth? A. The front row at a Willie Nelson Concert.
#
# ...
